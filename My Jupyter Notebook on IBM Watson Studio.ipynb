# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **KOMI Koffi Honoré**
#
# Futur Data Scientist

# %% [markdown]
# *I'm interested in data science because I fell in love with numbers through Excel recently and really want to learn about the process of using data to understand different things and help make better decisions.*

# %% [markdown]
# ### I am going to write a code that will provide information on the sum of the digits 10 and 15, which will give as an answer 25

# %%
10+15
# Out:
# 25
